# %%
#import dependencies
import pandas as pd
import requests
import json
from config import api_key
from census import Census
from us import states

# %%
#start 2010 session
c = Census(api_key, year = 2010)

# %%
#view tables
c.acs5.tables()
# Out:
# [{'name': 'B17015',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY SOCIAL SECURITY INCOME BY SUPPLEMENTAL SECURITY INCOME (SSI) AND CASH PUBLIC ASSISTANCE INCOME',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17015.json'},
#  {'name': 'B17016',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY WORK EXPERIENCE OF HOUSEHOLDER AND SPOUSE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17016.json'},
#  {'name': 'B17017',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS BY HOUSEHOLD TYPE BY AGE OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17017.json'},
#  {'name': 'B17018',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17018.json'},
#  {'name': 'B17011',
#   'description': 'AGGREGATE INCOME DEFICIT (DOLLARS) IN THE PAST 12 MONTHS FOR FAMILIES BY FAMILY TYPE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17011.json'},
#  {'name': 'B19301A',
#   'description': 'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19301A.json'},
#  {'name': 'B07001PR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07001PR.json'},
#  {'name': 'B17012',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY NUMBER OF RELATED CHILDREN UNDER 18 YEARS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17012.json'},
#  {'name': 'B17013',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY NUMBER OF PERSONS IN FAMILY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17013.json'},
#  {'name': 'B17014',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY NUMBER OF WORKERS IN FAMILY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17014.json'},
#  {'name': 'B19301E',
#   'description': 'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19301E.json'},
#  {'name': 'B19301D',
#   'description': 'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (ASIAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19301D.json'},
#  {'name': 'B19301C',
#   'description': 'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19301C.json'},
#  {'name': 'B17010',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17010.json'},
#  {'name': 'B19301B',
#   'description': 'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19301B.json'},
#  {'name': 'B19301I',
#   'description': 'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19301I.json'},
#  {'name': 'B98013',
#   'description': 'TOTAL POPULATION COVERAGE RATE BY WEIGHTING RACE AND HISPANIC OR LATINO GROUPS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B98013.json'},
#  {'name': 'B99102',
#   'description': 'IMPUTATION OF GRANDPARENTS LIVING WITH GRANDCHILDREN UNDER 18 YEARS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B99102.json'},
#  {'name': 'B19301H',
#   'description': 'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19301H.json'},
#  {'name': 'B98012',
#   'description': 'TOTAL POPULATION COVERAGE RATE BY SEX',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B98012.json'},
#  {'name': 'B19301G',
#   'description': 'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (TWO OR MORE RACES)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19301G.json'},
#  {'name': 'B99104',
#   'description': 'IMPUTATION OF LENGTH OF TIME GRANDPARENT RESPONSIBLE FOR OWN GRANDCHILDREN UNDER 18 YEARS FOR THE POPULATION 30 YEARS AND OVER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B99104.json'},
#  {'name': 'B19301F',
#   'description': 'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (SOME OTHER RACE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19301F.json'},
#  {'name': 'B98014',
#   'description': 'GROUP QUARTERS POPULATION COVERAGE RATE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B98014.json'},
#  {'name': 'B99103',
#   'description': 'IMPUTATION OF GRANDPARENTS RESPONSIBLE FOR GRANDCHILDREN UNDER 18 YEARS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B99103.json'},
#  {'name': 'B08536',
#   'description': 'AGGREGATE TRAVEL TIME TO WORK (IN MINUTES) OF WORKERS BY MEANS OF TRANSPORTATION TO WORK FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08536.json'},
#  {'name': 'B08537',
#   'description': 'MEANS OF TRANSPORTATION TO WORK BY TENURE FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08537.json'},
#  {'name': 'B08534',
#   'description': 'MEANS OF TRANSPORTATION TO WORK BY TRAVEL TIME TO WORK FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08534.json'},
#  {'name': 'B98011',
#   'description': 'HOUSING UNIT COVERAGE RATE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B98011.json'},
#  {'name': 'B07204',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--STATE, COUNTY AND PLACE LEVEL IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07204.json'},
#  {'name': 'B07408PR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07408PR.json'},
#  {'name': 'B08532',
#   'description': 'MEANS OF TRANSPORTATION TO WORK BY TIME ARRIVING AT WORK FROM HOME FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08532.json'},
#  {'name': 'B07404APR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE) FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07404APR.json'},
#  {'name': 'B17019',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY TENURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17019.json'},
#  {'name': 'B17004',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF INDIVIDUALS BY SEX BY WORK EXPERIENCE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17004.json'},
#  {'name': 'B17005',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF INDIVIDUALS BY SEX BY EMPLOYMENT STATUS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17005.json'},
#  {'name': 'B17006',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF RELATED CHILDREN UNDER 18 YEARS BY FAMILY TYPE BY AGE OF RELATED CHILDREN UNDER 18 YEARS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17006.json'},
#  {'name': 'B17007',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF UNRELATED INDIVIDUALS 15 YEARS AND OVER BY SEX BY AGE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17007.json'},
#  {'name': 'B07012PR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY POVERTY STATUS IN THE PAST 12 MONTHS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07012PR.json'},
#  {'name': 'B17001',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS BY SEX BY AGE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17001.json'},
#  {'name': 'B17003',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF INDIVIDUALS BY SEX BY EDUCATIONAL ATTAINMENT',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17003.json'},
#  {'name': 'B98022',
#   'description': 'GROUP QUARTERS POPULATION RESPONSE AND NONRESPONSE RATES WITH REASONS FOR NONINTERVIEWS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B98022.json'},
#  {'name': 'B08303',
#   'description': 'TRAVEL TIME TO WORK',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08303.json'},
#  {'name': 'B98021',
#   'description': 'HOUSING UNIT RESPONSE AND NONRESPONSE RATES WITH REASONS FOR NONINTERVIEWS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B98021.json'},
#  {'name': 'B08301',
#   'description': 'MEANS OF TRANSPORTATION TO WORK',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08301.json'},
#  {'name': 'B08302',
#   'description': 'TIME LEAVING HOME TO GO TO WORK',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08302.json'},
#  {'name': 'B08541',
#   'description': 'MEANS OF TRANSPORTATION TO WORK BY VEHICLES AVAILABLE FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08541.json'},
#  {'name': 'B17009',
#   'description': 'POVERTY STATUS BY WORK EXPERIENCE OF UNRELATED INDIVIDUALS BY HOUSEHOLDER STATUS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17009.json'},
#  {'name': 'B05008',
#   'description': 'SEX BY PLACE OF BIRTH BY YEAR OF ENTRY FOR THE FOREIGN-BORN POPULATION',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B05008.json'},
#  {'name': 'B05007',
#   'description': 'PLACE OF BIRTH BY YEAR OF ENTRY BY CITIZENSHIP STATUS FOR THE FOREIGN-BORN POPULATION',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B05007.json'},
#  {'name': 'B06004HPR',
#   'description': 'PLACE OF BIRTH (WHITE ALONE, NOT HISPANIC OR LATINO) IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B06004HPR.json'},
#  {'name': 'B08519',
#   'description': "MEANS OF TRANSPORTATION TO WORK BY WORKERS' EARNINGS IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR WORKPLACE GEOGRAPHY",
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08519.json'},
#  {'name': 'B05009',
#   'description': 'AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY NUMBER AND NATIVITY OF PARENTS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B05009.json'},
#  {'name': 'B05004',
#   'description': 'MEDIAN AGE BY CITIZENSHIP STATUS BY SEX',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B05004.json'},
#  {'name': 'B25097',
#   'description': 'MORTGAGE STATUS BY MEDIAN VALUE (DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25097.json'},
#  {'name': 'B05003',
#   'description': 'SEX BY AGE BY CITIZENSHIP STATUS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B05003.json'},
#  {'name': 'B25096',
#   'description': 'MORTGAGE STATUS BY VALUE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25096.json'},
#  {'name': 'B05006',
#   'description': 'PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B05006.json'},
#  {'name': 'B25099',
#   'description': 'MORTGAGE STATUS BY MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25099.json'},
#  {'name': 'B05005',
#   'description': 'YEAR OF ENTRY BY CITIZENSHIP STATUS IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B05005.json'},
#  {'name': 'B25098',
#   'description': 'MORTGAGE STATUS BY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25098.json'},
#  {'name': 'B08513',
#   'description': 'MEANS OF TRANSPORTATION TO WORK BY LANGUAGE SPOKEN AT HOME AND ABILITY TO SPEAK ENGLISH FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08513.json'},
#  {'name': 'B08511',
#   'description': 'MEANS OF TRANSPORTATION TO WORK BY CITIZENSHIP STATUS FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08511.json'},
#  {'name': 'B05002',
#   'description': 'PLACE OF BIRTH BY CITIZENSHIP STATUS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B05002.json'},
#  {'name': 'B05001',
#   'description': 'CITIZENSHIP STATUS IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B05001.json'},
#  {'name': 'B25091',
#   'description': 'MORTGAGE STATUS BY SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25091.json'},
#  {'name': 'B25090',
#   'description': 'MORTGAGE STATUS BY AGGREGATE REAL ESTATE TAXES PAID (DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25090.json'},
#  {'name': 'B25093',
#   'description': 'AGE OF HOUSEHOLDER BY SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25093.json'},
#  {'name': 'B25092',
#   'description': 'MEDIAN SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25092.json'},
#  {'name': 'B25094',
#   'description': 'SELECTED MONTHLY OWNER COSTS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25094.json'},
#  {'name': 'B07004DPR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (ASIAN ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07004DPR.json'},
#  {'name': 'B98002',
#   'description': 'UNWEIGHTED GROUP QUARTERS POPULATION SAMPLE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B98002.json'},
#  {'name': 'B98001',
#   'description': 'UNWEIGHTED HOUSING UNIT SAMPLE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B98001.json'},
#  {'name': 'B08528',
#   'description': 'MEANS OF TRANSPORTATION TO WORK BY CLASS OF WORKER FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08528.json'},
#  {'name': 'B25086',
#   'description': 'AGGREGATE PRICE ASKED (DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25086.json'},
#  {'name': 'B08526',
#   'description': 'MEANS OF TRANSPORTATION TO WORK BY INDUSTRY FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08526.json'},
#  {'name': 'B25085',
#   'description': 'PRICE ASKED',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25085.json'},
#  {'name': 'B25088',
#   'description': 'MEDIAN SELECTED MONTHLY OWNER COSTS (DOLLARS) BY MORTGAGE STATUS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25088.json'},
#  {'name': 'B08524',
#   'description': 'MEANS OF TRANSPORTATION TO WORK BY OCCUPATION FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08524.json'},
#  {'name': 'B25087',
#   'description': 'MORTGAGE STATUS AND SELECTED MONTHLY OWNER COSTS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25087.json'},
#  {'name': 'B25014I',
#   'description': 'OCCUPANTS PER ROOM (HISPANIC OR LATINO HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25014I.json'},
#  {'name': 'B01001F',
#   'description': 'SEX BY AGE (SOME OTHER RACE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01001F.json'},
#  {'name': 'B08521',
#   'description': 'MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) BY MEANS OF TRANSPORTATION TO WORK FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08521.json'},
#  {'name': 'B08522',
#   'description': 'MEANS OF TRANSPORTATION TO WORK BY POVERTY STATUS IN THE PAST 12 MONTHS FOR WORKPLACE GEOGRAPHY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08522.json'},
#  {'name': 'B25014H',
#   'description': 'OCCUPANTS PER ROOM (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25014H.json'},
#  {'name': 'B01001G',
#   'description': 'SEX BY AGE (TWO OR MORE RACES)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01001G.json'},
#  {'name': 'B25089',
#   'description': 'AGGREGATE SELECTED MONTHLY OWNER COSTS (DOLLARS) BY MORTGAGE STATUS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25089.json'},
#  {'name': 'B05010',
#   'description': 'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS BY NATIVITY OF CHILDREN UNDER 18 YEARS IN FAMILIES AND SUBFAMILIES BY LIVING ARRANGEMENTS AND NATIVITY OF PARENTS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B05010.json'},
#  {'name': 'B25014G',
#   'description': 'OCCUPANTS PER ROOM (TWO OR MORE RACES HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25014G.json'},
#  {'name': 'B01001H',
#   'description': 'SEX BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01001H.json'},
#  {'name': 'B25014F',
#   'description': 'OCCUPANTS PER ROOM (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25014F.json'},
#  {'name': 'B01001I',
#   'description': 'SEX BY AGE (HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01001I.json'},
#  {'name': 'B05012',
#   'description': 'NATIVITY IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B05012.json'},
#  {'name': 'B25014E',
#   'description': 'OCCUPANTS PER ROOM (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25014E.json'},
#  {'name': 'B01001B',
#   'description': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01001B.json'},
#  {'name': 'B25014D',
#   'description': 'OCCUPANTS PER ROOM (ASIAN ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25014D.json'},
#  {'name': 'B01001C',
#   'description': 'SEX BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01001C.json'},
#  {'name': 'B25014C',
#   'description': 'OCCUPANTS PER ROOM (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25014C.json'},
#  {'name': 'B01001D',
#   'description': 'SEX BY AGE (ASIAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01001D.json'},
#  {'name': 'B25080',
#   'description': 'AGGREGATE VALUE (DOLLARS) BY UNITS IN STRUCTURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25080.json'},
#  {'name': 'B25014B',
#   'description': 'OCCUPANTS PER ROOM (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25014B.json'},
#  {'name': 'B01001E',
#   'description': 'SEX BY AGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01001E.json'},
#  {'name': 'B25014A',
#   'description': 'OCCUPANTS PER ROOM (WHITE ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25014A.json'},
#  {'name': 'B25082',
#   'description': 'AGGREGATE VALUE (DOLLARS) BY MORTGAGE STATUS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25082.json'},
#  {'name': 'B25081',
#   'description': 'MORTGAGE STATUS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25081.json'},
#  {'name': 'B01001A',
#   'description': 'SEX BY AGE (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01001A.json'},
#  {'name': 'B25083',
#   'description': 'MEDIAN VALUE (DOLLARS) FOR MOBILE HOMES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25083.json'},
#  {'name': 'B12007C',
#   'description': 'MEDIAN AGE AT FIRST MARRIAGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12007C.json'},
#  {'name': 'B12007B',
#   'description': 'MEDIAN AGE AT FIRST MARRIAGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12007B.json'},
#  {'name': 'B12007A',
#   'description': 'MEDIAN AGE AT FIRST MARRIAGE (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12007A.json'},
#  {'name': 'B07003PR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07003PR.json'},
#  {'name': 'B07009',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07009.json'},
#  {'name': 'B07008',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07008.json'},
#  {'name': 'B07007',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07007.json'},
#  {'name': 'B01002G',
#   'description': 'MEDIAN AGE BY SEX (TWO OR MORE RACES)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01002G.json'},
#  {'name': 'B07002',
#   'description': 'MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07002.json'},
#  {'name': 'B01002H',
#   'description': 'MEDIAN AGE BY SEX (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01002H.json'},
#  {'name': 'B07001',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07001.json'},
#  {'name': 'B01002I',
#   'description': 'MEDIAN AGE BY SEX (HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01002I.json'},
#  {'name': 'B07003',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07003.json'},
#  {'name': 'B01002C',
#   'description': 'MEDIAN AGE BY SEX (AMERICAN INDIAN AND ALASKA NATIVE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01002C.json'},
#  {'name': 'B01002D',
#   'description': 'MEDIAN AGE BY SEX (ASIAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01002D.json'},
#  {'name': 'B12007I',
#   'description': 'MEDIAN AGE AT FIRST MARRIAGE (HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12007I.json'},
#  {'name': 'B01002E',
#   'description': 'MEDIAN AGE BY SEX (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01002E.json'},
#  {'name': 'B07404CPR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (AMERICAN INDIAN AND ALASKA NATIVE ALONE) FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07404CPR.json'},
#  {'name': 'B12007H',
#   'description': 'MEDIAN AGE AT FIRST MARRIAGE (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12007H.json'},
#  {'name': 'B01002F',
#   'description': 'MEDIAN AGE BY SEX (SOME OTHER RACE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01002F.json'},
#  {'name': 'B12007G',
#   'description': 'MEDIAN AGE AT FIRST MARRIAGE (TWO OR MORE RACES)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12007G.json'},
#  {'name': 'B12007F',
#   'description': 'MEDIAN AGE AT FIRST MARRIAGE (SOME OTHER RACE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12007F.json'},
#  {'name': 'B12007E',
#   'description': 'MEDIAN AGE AT FIRST MARRIAGE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12007E.json'},
#  {'name': 'B01002A',
#   'description': 'MEDIAN AGE BY SEX (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01002A.json'},
#  {'name': 'B12007D',
#   'description': 'MEDIAN AGE AT FIRST MARRIAGE (ASIAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12007D.json'},
#  {'name': 'B01002B',
#   'description': 'MEDIAN AGE BY SEX (BLACK OR AFRICAN AMERICAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B01002B.json'},
#  {'name': 'B25032I',
#   'description': 'UNITS IN STRUCTURE (HISPANIC OR LATINO HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25032I.json'},
#  {'name': 'B25032H',
#   'description': 'UNITS IN STRUCTURE (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25032H.json'},
#  {'name': 'B25032G',
#   'description': 'UNITS IN STRUCTURE (TWO OR MORE RACES HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25032G.json'},
#  {'name': 'B25032F',
#   'description': 'UNITS IN STRUCTURE (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25032F.json'},
#  {'name': 'B25032E',
#   'description': 'UNITS IN STRUCTURE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25032E.json'},
#  {'name': 'B06003PR',
#   'description': 'PLACE OF BIRTH BY SEX IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B06003PR.json'},
#  {'name': 'B07013',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY TENURE FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07013.json'},
#  {'name': 'B08103',
#   'description': 'MEDIAN AGE BY MEANS OF TRANSPORTATION TO WORK',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08103.json'},
#  {'name': 'B25032D',
#   'description': 'UNITS IN STRUCTURE (ASIAN ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25032D.json'},
#  {'name': 'B07012',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY POVERTY STATUS IN THE PAST 12 MONTHS FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07012.json'},
#  {'name': 'B25032C',
#   'description': 'UNITS IN STRUCTURE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25032C.json'},
#  {'name': 'B08101',
#   'description': 'MEANS OF TRANSPORTATION TO WORK BY AGE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08101.json'},
#  {'name': 'B25032B',
#   'description': 'UNITS IN STRUCTURE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25032B.json'},
#  {'name': 'B25032A',
#   'description': 'UNITS IN STRUCTURE (WHITE ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25032A.json'},
#  {'name': 'B07011',
#   'description': 'MEDIAN INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07011.json'},
#  {'name': 'B07010',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07010.json'},
#  {'name': 'B99052PR',
#   'description': 'IMPUTATION OF YEAR OF ENTRY FOR POPULATION BORN OUTSIDE PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B99052PR.json'},
#  {'name': 'B19216',
#   'description': 'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19216.json'},
#  {'name': 'B19215',
#   'description': 'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19215.json'},
#  {'name': 'B19214',
#   'description': 'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19214.json'},
#  {'name': 'B06004FPR',
#   'description': 'PLACE OF BIRTH (SOME OTHER RACE ALONE) IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B06004FPR.json'},
#  {'name': 'B11001B',
#   'description': 'HOUSEHOLD TYPE (INCLUDING LIVING ALONE) (BLACK OR AFRICAN AMERICAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11001B.json'},
#  {'name': 'B11001A',
#   'description': 'HOUSEHOLD TYPE (INCLUDING LIVING ALONE) (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11001A.json'},
#  {'name': 'B11001D',
#   'description': 'HOUSEHOLD TYPE (INCLUDING LIVING ALONE) (ASIAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11001D.json'},
#  {'name': 'B11001C',
#   'description': 'HOUSEHOLD TYPE (INCLUDING LIVING ALONE) (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11001C.json'},
#  {'name': 'B11001F',
#   'description': 'HOUSEHOLD TYPE (INCLUDING LIVING ALONE) (SOME OTHER RACE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11001F.json'},
#  {'name': 'B11001E',
#   'description': 'HOUSEHOLD TYPE (INCLUDING LIVING ALONE) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11001E.json'},
#  {'name': 'B11001H',
#   'description': 'HOUSEHOLD TYPE (INCLUDING LIVING ALONE) (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11001H.json'},
#  {'name': 'B11001G',
#   'description': 'HOUSEHOLD TYPE (INCLUDING LIVING ALONE) (TWO OR MORE RACES)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11001G.json'},
#  {'name': 'B11001I',
#   'description': 'HOUSEHOLD TYPE (INCLUDING LIVING ALONE) (HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11001I.json'},
#  {'name': 'B17026',
#   'description': 'RATIO OF INCOME TO POVERTY LEVEL OF FAMILIES IN THE PAST 12 MONTHS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17026.json'},
#  {'name': 'B17022',
#   'description': 'RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17022.json'},
#  {'name': 'B19201',
#   'description': 'NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19201.json'},
#  {'name': 'B07004FPR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (SOME OTHER RACE ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07004FPR.json'},
#  {'name': 'B17023',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY NUMBER OF OWN CHILDREN UNDER 18 YEARS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17023.json'},
#  {'name': 'B17024',
#   'description': 'AGE BY RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17024.json'},
#  {'name': 'B17025',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS BY NATIVITY',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17025.json'},
#  {'name': 'B19202',
#   'description': 'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19202.json'},
#  {'name': 'B17021',
#   'description': 'POVERTY STATUS OF INDIVIDUALS IN THE PAST 12 MONTHS BY LIVING ARRANGEMENT',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17021.json'},
#  {'name': 'B11002A',
#   'description': 'HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11002A.json'},
#  {'name': 'B11002C',
#   'description': 'HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11002C.json'},
#  {'name': 'B11002B',
#   'description': 'HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (BLACK OR AFRICAN AMERICAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11002B.json'},
#  {'name': 'B11002E',
#   'description': 'HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11002E.json'},
#  {'name': 'B11002D',
#   'description': 'HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (ASIAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11002D.json'},
#  {'name': 'B11002G',
#   'description': 'HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (TWO OR MORE RACES)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11002G.json'},
#  {'name': 'B11002F',
#   'description': 'HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (SOME OTHER RACE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11002F.json'},
#  {'name': 'B11002I',
#   'description': 'HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11002I.json'},
#  {'name': 'B11002H',
#   'description': 'HOUSEHOLD TYPE BY RELATIVES AND NONRELATIVES FOR POPULATION IN HOUSEHOLDS (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B11002H.json'},
#  {'name': 'B25039',
#   'description': 'MEDIAN YEAR HOUSEHOLDER MOVED INTO UNIT BY TENURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25039.json'},
#  {'name': 'B25038',
#   'description': 'TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25038.json'},
#  {'name': 'B03001',
#   'description': 'HISPANIC OR LATINO ORIGIN BY SPECIFIC ORIGIN',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B03001.json'},
#  {'name': 'B03002',
#   'description': 'HISPANIC OR LATINO ORIGIN BY RACE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B03002.json'},
#  {'name': 'B03003',
#   'description': 'HISPANIC OR LATINO ORIGIN',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B03003.json'},
#  {'name': 'B25033',
#   'description': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY UNITS IN STRUCTURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25033.json'},
#  {'name': 'B25032',
#   'description': 'TENURE BY UNITS IN STRUCTURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25032.json'},
#  {'name': 'B25035',
#   'description': 'MEDIAN YEAR STRUCTURE BUILT',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25035.json'},
#  {'name': 'B25034',
#   'description': 'YEAR STRUCTURE BUILT',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25034.json'},
#  {'name': 'B25037',
#   'description': 'MEDIAN YEAR STRUCTURE BUILT BY TENURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25037.json'},
#  {'name': 'B25036',
#   'description': 'TENURE BY YEAR STRUCTURE BUILT',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25036.json'},
#  {'name': 'B25027',
#   'description': 'MORTGAGE STATUS BY AGE OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25027.json'},
#  {'name': 'B25020',
#   'description': 'TENURE BY ROOMS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25020.json'},
#  {'name': 'B25022',
#   'description': 'AGGREGATE NUMBER OF ROOMS BY TENURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25022.json'},
#  {'name': 'B06001PR',
#   'description': 'PLACE OF BIRTH BY AGE IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B06001PR.json'},
#  {'name': 'B25021',
#   'description': 'MEDIAN NUMBER OF ROOMS BY TENURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25021.json'},
#  {'name': 'B25024',
#   'description': 'UNITS IN STRUCTURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25024.json'},
#  {'name': 'B25023',
#   'description': 'AGGREGATE NUMBER OF ROOMS BY VACANCY STATUS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25023.json'},
#  {'name': 'B25026',
#   'description': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE BY YEAR HOUSEHOLDER MOVED INTO UNIT',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25026.json'},
#  {'name': 'B25017',
#   'description': 'ROOMS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25017.json'},
#  {'name': 'B25016',
#   'description': 'TENURE BY PLUMBING FACILITIES BY OCCUPANTS PER ROOM',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25016.json'},
#  {'name': 'B25019',
#   'description': 'AGGREGATE NUMBER OF ROOMS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25019.json'},
#  {'name': 'B25018',
#   'description': 'MEDIAN NUMBER OF ROOMS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25018.json'},
#  {'name': 'B25011',
#   'description': 'TENURE BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25011.json'},
#  {'name': 'B06012PR',
#   'description': 'PLACE OF BIRTH BY POVERTY STATUS IN THE PAST 12 MONTHS IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B06012PR.json'},
#  {'name': 'B25010',
#   'description': 'AVERAGE HOUSEHOLD SIZE OF OCCUPIED HOUSING UNITS BY TENURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25010.json'},
#  {'name': 'B25013',
#   'description': 'TENURE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25013.json'},
#  {'name': 'B25012',
#   'description': 'TENURE BY FAMILIES AND PRESENCE OF OWN CHILDREN',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25012.json'},
#  {'name': 'B25015',
#   'description': 'TENURE BY AGE OF HOUSEHOLDER BY OCCUPANTS PER ROOM',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25015.json'},
#  {'name': 'B25014',
#   'description': 'TENURE BY OCCUPANTS PER ROOM',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25014.json'},
#  {'name': 'B07004HPR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE, NOT HISPANIC OR LATINO) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07004HPR.json'},
#  {'name': 'B25006',
#   'description': 'RACE OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25006.json'},
#  {'name': 'B25005',
#   'description': 'VACANT - CURRENT RESIDENCE ELSEWHERE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25005.json'},
#  {'name': 'B25008',
#   'description': 'TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25008.json'},
#  {'name': 'B25007',
#   'description': 'TENURE BY AGE OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25007.json'},
#  {'name': 'B25009',
#   'description': 'TENURE BY HOUSEHOLD SIZE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25009.json'},
#  {'name': 'B25002',
#   'description': 'OCCUPANCY STATUS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25002.json'},
#  {'name': 'B12002I',
#   'description': 'SEX BY MARITAL STATUS FOR THE POPULATION 15 YEARS AND OVER (HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12002I.json'},
#  {'name': 'B25001',
#   'description': 'HOUSING UNITS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25001.json'},
#  {'name': 'B12002H',
#   'description': 'SEX BY MARITAL STATUS FOR THE POPULATION 15 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12002H.json'},
#  {'name': 'B25004',
#   'description': 'VACANCY STATUS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25004.json'},
#  {'name': 'B12002G',
#   'description': 'SEX BY MARITAL STATUS FOR THE POPULATION 15 YEARS AND OVER (TWO OR MORE RACES)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12002G.json'},
#  {'name': 'B25003',
#   'description': 'TENURE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25003.json'},
#  {'name': 'B12002F',
#   'description': 'SEX BY MARITAL STATUS FOR THE POPULATION 15 YEARS AND OVER (SOME OTHER RACE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12002F.json'},
#  {'name': 'B12002E',
#   'description': 'SEX BY MARITAL STATUS FOR THE POPULATION 15 YEARS AND OVER (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12002E.json'},
#  {'name': 'B12002D',
#   'description': 'SEX BY MARITAL STATUS FOR THE POPULATION 15 YEARS AND OVER (ASIAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12002D.json'},
#  {'name': 'B12002C',
#   'description': 'SEX BY MARITAL STATUS FOR THE POPULATION 15 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12002C.json'},
#  {'name': 'B12002B',
#   'description': 'SEX BY MARITAL STATUS FOR THE POPULATION 15 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12002B.json'},
#  {'name': 'B12002A',
#   'description': 'SEX BY MARITAL STATUS FOR THE POPULATION 15 YEARS AND OVER (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B12002A.json'},
#  {'name': 'B07402PR',
#   'description': 'MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07402PR.json'},
#  {'name': 'B07409',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY EDUCATIONAL ATTAINMENT FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07409.json'},
#  {'name': 'B07407',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07407.json'},
#  {'name': 'B07408',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY MARITAL STATUS FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07408.json'},
#  {'name': 'B25075',
#   'description': 'VALUE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25075.json'},
#  {'name': 'B07403',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY SEX FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07403.json'},
#  {'name': 'B25074',
#   'description': 'HOUSEHOLD INCOME BY GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25074.json'},
#  {'name': 'B25077',
#   'description': 'MEDIAN VALUE (DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25077.json'},
#  {'name': 'B07401',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07401.json'},
#  {'name': 'B25076',
#   'description': 'LOWER VALUE QUARTILE (DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25076.json'},
#  {'name': 'B07402',
#   'description': 'MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR RESIDENCE 1 YEAR AGO IN THE UNITED STATES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07402.json'},
#  {'name': 'B25079',
#   'description': 'AGGREGATE VALUE (DOLLARS) BY AGE OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25079.json'},
#  {'name': 'B25078',
#   'description': 'UPPER VALUE QUARTILE (DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25078.json'},
#  {'name': 'B25071',
#   'description': 'MEDIAN GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS (DOLLARS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25071.json'},
#  {'name': 'B25070',
#   'description': 'GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25070.json'},
#  {'name': 'B25073',
#   'description': 'UNITS IN STRUCTURE BY GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25073.json'},
#  {'name': 'B07007PR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07007PR.json'},
#  {'name': 'B25072',
#   'description': 'AGE OF HOUSEHOLDER BY GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B25072.json'},
#  {'name': 'B07203PR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR FOR CURRENT RESIDENCE--NOT METROPOLITAN OR MICROPOLITAN STATISTICAL AREA LEVEL IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07203PR.json'},
#  {'name': 'B08105A',
#   'description': 'MEANS OF TRANSPORTATION TO WORK (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B08105A.json'},
#  {'name': 'B08105B',
#   'description': 'MEANS OF TRANSPORTATION TO WORK (BLACK OR AFRICAN AMERICAN ALONE)',
# ...
#  {'name': 'B22008',
#   'description': 'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) BY RECEIPT OF FOOD STAMPS/SNAP IN THE PAST 12 MONTHS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B22008.json'},
#  {'name': 'B22007',
#   'description': 'RECEIPT OF FOOD STAMPS/SNAP IN THE PAST 12 MONTHS BY FAMILY TYPE BY NUMBER OF WORKERS IN FAMILY IN THE PAST 12 MONTHS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B22007.json'},
#  {'name': 'B22003',
#   'description': 'RECEIPT OF FOOD STAMPS/SNAP IN THE PAST 12 MONTHS BY POVERTY STATUS IN THE PAST 12 MONTHS FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B22003.json'},
#  {'name': 'B22002',
#   'description': 'RECEIPT OF FOOD STAMPS/SNAP IN THE PAST 12 MONTHS BY PRESENCE OF CHILDREN UNDER 18 YEARS BY HOUSEHOLD TYPE FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B22002.json'},
#  {'name': 'B06004CPR',
#   'description': 'PLACE OF BIRTH (AMERICAN INDIAN AND ALASKA NATIVE ALONE) IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B06004CPR.json'},
#  {'name': 'B99142',
#   'description': 'IMPUTATION OF GRADE ENROLLED FOR THE POPULATION 3 YEARS AND OVER ENROLLED IN SCHOOL',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B99142.json'},
#  {'name': 'C24010A',
#   'description': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/C24010A.json'},
#  {'name': 'B99141',
#   'description': 'IMPUTATION OF SCHOOL ENROLLMENT FOR THE POPULATION 3 YEARS AND OVER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B99141.json'},
#  {'name': 'B19080',
#   'description': 'HOUSEHOLD INCOME QUINTILE UPPER LIMITS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19080.json'},
#  {'name': 'B19081',
#   'description': 'MEAN HOUSEHOLD INCOME OF QUINTILES',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19081.json'},
#  {'name': 'B17020H',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17020H.json'},
#  {'name': 'B17020I',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17020I.json'},
#  {'name': 'B17020F',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (SOME OTHER RACE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17020F.json'},
#  {'name': 'B07404GPR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (TWO OR MORE RACES) FOR RESIDENCE 1 YEAR AGO IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07404GPR.json'},
#  {'name': 'B17020G',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (TWO OR MORE RACES)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B17020G.json'},
#  {'name': 'B22001',
#   'description': 'RECEIPT OF FOOD STAMPS/SNAP IN THE PAST 12 MONTHS BY PRESENCE OF PEOPLE 60 YEARS AND OVER FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B22001.json'},
#  {'name': 'C24010I',
#   'description': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/C24010I.json'},
#  {'name': 'C24010H',
#   'description': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/C24010H.json'},
#  {'name': 'C24010G',
#   'description': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (TWO OR MORE RACES)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/C24010G.json'},
#  {'name': 'C24010F',
#   'description': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (SOME OTHER RACE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/C24010F.json'},
#  {'name': 'C24010E',
#   'description': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/C24010E.json'},
#  {'name': 'C24010D',
#   'description': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (ASIAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/C24010D.json'},
#  {'name': 'C24010C',
#   'description': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/C24010C.json'},
#  {'name': 'C24010B',
#   'description': 'SEX BY OCCUPATION FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/C24010B.json'},
#  {'name': 'B07004APR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR (WHITE ALONE) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07004APR.json'},
#  {'name': 'B19069',
#   'description': 'AGGREGATE RETIREMENT INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19069.json'},
#  {'name': 'B10010',
#   'description': 'MEDIAN FAMILY INCOME FOR FAMILIES WITH GRANDPARENT HOUSEHOLDERS AND/OR SPOUSES LIVING WITH OWN GRANDCHILDREN UNDER 18 YEARS BY RESPONSIBILITY FOR OWN GRANDCHILDREN AND PRESENCE OF PARENT OF GRANDCHILDREN',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B10010.json'},
#  {'name': 'B07010PR',
#   'description': 'GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDIVIDUAL INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR CURRENT RESIDENCE IN PUERTO RICO',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B07010PR.json'},
#  {'name': 'B19064',
#   'description': 'AGGREGATE INTEREST, DIVIDENDS, OR NET RENTAL INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19064.json'},
#  {'name': 'B19065',
#   'description': 'AGGREGATE SOCIAL SECURITY INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19065.json'},
#  {'name': 'B19066',
#   'description': 'AGGREGATE SUPPLEMENTAL SECURITY INCOME (SSI) IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19066.json'},
#  {'name': 'B19067',
#   'description': 'AGGREGATE PUBLIC ASSISTANCE INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19067.json'},
#  {'name': 'B19060',
#   'description': 'OTHER TYPES OF INCOME IN THE PAST 12 MONTHS FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19060.json'},
#  {'name': 'B19061',
#   'description': 'AGGREGATE EARNINGS IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19061.json'},
#  {'name': 'B19062',
#   'description': 'AGGREGATE WAGE OR SALARY INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19062.json'},
#  {'name': 'B19063',
#   'description': 'AGGREGATE SELF-EMPLOYMENT INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19063.json'},
#  {'name': 'B19113I',
#   'description': 'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (HISPANIC OR LATINO HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19113I.json'},
#  {'name': 'B19070',
#   'description': 'AGGREGATE OTHER TYPES OF INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19070.json'},
#  {'name': 'B99151',
#   'description': 'IMPUTATION OF EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B99151.json'},
#  {'name': 'B19057',
#   'description': 'PUBLIC ASSISTANCE INCOME IN THE PAST 12 MONTHS FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19057.json'},
#  {'name': 'B19202A',
#   'description': 'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19202A.json'},
#  {'name': 'B19058',
#   'description': 'PUBLIC ASSISTANCE INCOME OR FOOD STAMPS/SNAP IN THE PAST 12 MONTHS FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19058.json'},
#  {'name': 'B19059',
#   'description': 'RETIREMENT INCOME IN THE PAST 12 MONTHS FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19059.json'},
#  {'name': 'B19053',
#   'description': 'SELF-EMPLOYMENT INCOME IN THE PAST 12 MONTHS FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19053.json'},
#  {'name': 'B19202E',
#   'description': 'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19202E.json'},
#  {'name': 'B19054',
#   'description': 'INTEREST, DIVIDENDS, OR NET RENTAL INCOME IN THE PAST 12 MONTHS FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19054.json'},
#  {'name': 'B19202D',
#   'description': 'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (ASIAN ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19202D.json'},
#  {'name': 'B19055',
#   'description': 'SOCIAL SECURITY INCOME IN THE PAST 12 MONTHS FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19055.json'},
#  {'name': 'B19202C',
#   'description': 'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19202C.json'},
#  {'name': 'B19056',
#   'description': 'SUPPLEMENTAL SECURITY INCOME (SSI) IN THE PAST 12 MONTHS FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19056.json'},
#  {'name': 'B19202B',
#   'description': 'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19202B.json'},
#  {'name': 'B19202I',
#   'description': 'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (HISPANIC OR LATINO HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19202I.json'},
#  {'name': 'B19050',
#   'description': 'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19050.json'},
#  {'name': 'B19202H',
#   'description': 'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19202H.json'},
#  {'name': 'B19051',
#   'description': 'EARNINGS IN THE PAST 12 MONTHS FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19051.json'},
#  {'name': 'B19202G',
#   'description': 'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (TWO OR MORE RACES HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19202G.json'},
#  {'name': 'B19052',
#   'description': 'WAGE OR SALARY INCOME IN THE PAST 12 MONTHS FOR HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19052.json'},
#  {'name': 'B19202F',
#   'description': 'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19202F.json'},
#  {'name': 'B98031',
#   'description': 'OVERALL PERSON CHARACTERISTIC IMPUTATION RATE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B98031.json'},
#  {'name': 'B09008',
#   'description': 'PRESENCE OF UNMARRIED PARTNER OF HOUSEHOLDER BY HOUSEHOLD TYPE FOR CHILDREN UNDER 18 YEARS IN HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B09008.json'},
#  {'name': 'B98032',
#   'description': 'OVERALL HOUSING UNIT CHARACTERISTIC IMPUTATION RATE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B98032.json'},
#  {'name': 'B99121',
#   'description': 'IMPUTATION OF MARITAL STATUS FOR THE POPULATION 15 YEARS AND OVER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B99121.json'},
#  {'name': 'B09005',
#   'description': 'HOUSEHOLD TYPE FOR CHILDREN UNDER 18 YEARS IN HOUSEHOLDS (EXCLUDING HOUSEHOLDERS, SPOUSES, AND UNMARRIED PARTNERS)',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B09005.json'},
#  {'name': 'B09006',
#   'description': 'RELATIONSHIP TO HOUSEHOLDER FOR CHILDREN UNDER 18 YEARS IN HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B09006.json'},
#  {'name': 'B09001',
#   'description': 'POPULATION UNDER 18 YEARS BY AGE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B09001.json'},
#  {'name': 'B10001',
#   'description': 'GRANDCHILDREN UNDER 18 YEARS LIVING WITH A GRANDPARENT HOUSEHOLDER BY AGE OF GRANDCHILD',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B10001.json'},
#  {'name': 'B09002',
#   'description': 'OWN CHILDREN UNDER 18 YEARS BY FAMILY TYPE AND AGE',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B09002.json'},
#  {'name': 'B10002',
#   'description': 'GRANDCHILDREN UNDER 18 YEARS LIVING WITH A GRANDPARENT HOUSEHOLDER BY GRANDPARENT RESPONSIBILITY AND PRESENCE OF PARENT',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B10002.json'},
#  {'name': 'B19049',
#   'description': 'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2010 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B19049.json'},
#  {'name': 'B99131',
#   'description': 'IMPUTATION OF MARITAL STATUS FOR FEMALES 15 TO 50 YEARS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B99131.json'},
#  {'name': 'B99132',
#   'description': 'IMPUTATION OF FERTILITY OF WOMEN 15 TO 50 YEARS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B99132.json'},
#  {'name': 'B09016',
#   'description': 'HOUSEHOLD TYPE (INCLUDING LIVING ALONE) BY RELATIONSHIP',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B09016.json'},
#  {'name': 'B09017',
#   'description': 'RELATIONSHIP BY HOUSEHOLD TYPE (INCLUDING LIVING ALONE) FOR THE POPULATION 65 YEARS AND OVER',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B09017.json'},
#  {'name': 'B09010',
#   'description': 'RECEIPT OF SUPPLEMENTAL SECURITY INCOME (SSI), CASH PUBLIC ASSISTANCE INCOME, OR FOOD STAMPS/SNAP IN THE PAST 12 MONTHS BY HOUSEHOLD TYPE FOR CHILDREN UNDER 18 YEARS IN HOUSEHOLDS',
#   'variables': 'https://api.census.gov/data/2010/acs/acs5/groups/B09010.json'}]

# %%
#test for state data call
c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), {'for': 'state:17'})
# Out:
# [{'NAME': 'Illinois',
#   'B19013_001E': 55735.0,
#   'B01003_001E': 12745359.0,
#   'B01002_001E': 36.2,
#   'B19301_001E': 28782.0,
#   'B17001_002E': 1572048.0,
#   'state': '17'}]

# %%
#state & county level data call
census_2010= c.acs5.state_county(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), "17", "*")

# %%
#create 2010 df
census_2010df = pd.DataFrame(census_2010)
census_2010df = census_2010df.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count", "state":"state_id", "county":"county_id"})
census_2010df.head()
# Out:
#                          NAME  Household Income  Population  Median Age  \
# 0      Adams County, Illinois           43824.0     67030.0        40.4
# 1  Alexander County, Illinois           28833.0      8449.0        41.8
# 2       Bond County, Illinois           51946.0     17904.0        39.3
# 3      Boone County, Illinois           61210.0     53567.0        35.8
# 4      Brown County, Illinois           38696.0      6897.0        37.6
#
#    Per Capita Income  Poverty Count state_id county_id
# 0            24308.0         7954.0       17       001
# 1            15858.0         1600.0       17       003
# 2            24341.0         1870.0       17       005
# 3            26105.0         5508.0       17       007
# 4            17133.0          555.0       17       009

# %%
#create census year column
census_year = "2010"
census_2010df["census_year"]=census_year
census_2010df.head()
# Out:
#                          NAME  Household Income  Population  Median Age  \
# 0      Adams County, Illinois           43824.0     67030.0        40.4
# 1  Alexander County, Illinois           28833.0      8449.0        41.8
# 2       Bond County, Illinois           51946.0     17904.0        39.3
# 3      Boone County, Illinois           61210.0     53567.0        35.8
# 4      Brown County, Illinois           38696.0      6897.0        37.6
#
#    Per Capita Income  Poverty Count state_id county_id census_year
# 0            24308.0         7954.0       17       001        2010
# 1            15858.0         1600.0       17       003        2010
# 2            24341.0         1870.0       17       005        2010
# 3            26105.0         5508.0       17       007        2010
# 4            17133.0          555.0       17       009        2010

# %%
#split name column into county and state columns
census_2010df[["county", "state"]] = census_2010df.NAME.str.split(",",expand=True)
census_2010df.head()
# Out:
#                          NAME  Household Income  Population  Median Age  \
# 0      Adams County, Illinois           43824.0     67030.0        40.4
# 1  Alexander County, Illinois           28833.0      8449.0        41.8
# 2       Bond County, Illinois           51946.0     17904.0        39.3
# 3      Boone County, Illinois           61210.0     53567.0        35.8
# 4      Brown County, Illinois           38696.0      6897.0        37.6
#
#    Per Capita Income  Poverty Count state_id county_id census_year  \
# 0            24308.0         7954.0       17       001        2010
# 1            15858.0         1600.0       17       003        2010
# 2            24341.0         1870.0       17       005        2010
# 3            26105.0         5508.0       17       007        2010
# 4            17133.0          555.0       17       009        2010
#
#              county      state
# 0      Adams County   Illinois
# 1  Alexander County   Illinois
# 2       Bond County   Illinois
# 3      Boone County   Illinois
# 4      Brown County   Illinois

# %%
#split string to be county name only
census_2010df['county2'] = census_2010df['county'].str.split(' ').str[0]
census_2010df.head()
# Out:
#                          NAME  Household Income  Population  Median Age  \
# 0      Adams County, Illinois           43824.0     67030.0        40.4
# 1  Alexander County, Illinois           28833.0      8449.0        41.8
# 2       Bond County, Illinois           51946.0     17904.0        39.3
# 3      Boone County, Illinois           61210.0     53567.0        35.8
# 4      Brown County, Illinois           38696.0      6897.0        37.6
#
#    Per Capita Income  Poverty Count state_id county_id census_year  \
# 0            24308.0         7954.0       17       001        2010
# 1            15858.0         1600.0       17       003        2010
# 2            24341.0         1870.0       17       005        2010
# 3            26105.0         5508.0       17       007        2010
# 4            17133.0          555.0       17       009        2010
#
#              county      state    county2
# 0      Adams County   Illinois      Adams
# 1  Alexander County   Illinois  Alexander
# 2       Bond County   Illinois       Bond
# 3      Boone County   Illinois      Boone
# 4      Brown County   Illinois      Brown

# %%
#drop old county column
census_2010df = census_2010df.drop(['county'], axis=1)
census_2010df.head()
# Out:
#                          NAME  Household Income  Population  Median Age  \
# 0      Adams County, Illinois           43824.0     67030.0        40.4
# 1  Alexander County, Illinois           28833.0      8449.0        41.8
# 2       Bond County, Illinois           51946.0     17904.0        39.3
# 3      Boone County, Illinois           61210.0     53567.0        35.8
# 4      Brown County, Illinois           38696.0      6897.0        37.6
#
#    Per Capita Income  Poverty Count state_id county_id census_year      state  \
# 0            24308.0         7954.0       17       001        2010   Illinois
# 1            15858.0         1600.0       17       003        2010   Illinois
# 2            24341.0         1870.0       17       005        2010   Illinois
# 3            26105.0         5508.0       17       007        2010   Illinois
# 4            17133.0          555.0       17       009        2010   Illinois
#
#      county2
# 0      Adams
# 1  Alexander
# 2       Bond
# 3      Boone
# 4      Brown

# %%
#drop old name column
census_2010df = census_2010df.drop(["NAME"], axis=1)
census_2010df.head()
# Out:
#    Household Income  Population  Median Age  Per Capita Income  Poverty Count  \
# 0           43824.0     67030.0        40.4            24308.0         7954.0
# 1           28833.0      8449.0        41.8            15858.0         1600.0
# 2           51946.0     17904.0        39.3            24341.0         1870.0
# 3           61210.0     53567.0        35.8            26105.0         5508.0
# 4           38696.0      6897.0        37.6            17133.0          555.0
#
#   state_id county_id census_year      state    county2
# 0       17       001        2010   Illinois      Adams
# 1       17       003        2010   Illinois  Alexander
# 2       17       005        2010   Illinois       Bond
# 3       17       007        2010   Illinois      Boone
# 4       17       009        2010   Illinois      Brown

# %%
#rename county2 to county
census_2010df = census_2010df.rename(columns={"county2": "county"})
census_2010df.head()
# Out:
#    Household Income  Population  Median Age  Per Capita Income  Poverty Count  \
# 0           43824.0     67030.0        40.4            24308.0         7954.0
# 1           28833.0      8449.0        41.8            15858.0         1600.0
# 2           51946.0     17904.0        39.3            24341.0         1870.0
# 3           61210.0     53567.0        35.8            26105.0         5508.0
# 4           38696.0      6897.0        37.6            17133.0          555.0
#
#   state_id county_id census_year      state     county
# 0       17       001        2010   Illinois      Adams
# 1       17       003        2010   Illinois  Alexander
# 2       17       005        2010   Illinois       Bond
# 3       17       007        2010   Illinois      Boone
# 4       17       009        2010   Illinois      Brown

# %%
#start 2014 session
c = Census(api_key, year = 2014)

# %%
#state & county level data call
census_2014= c.acs5.state_county(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), "17", "*")

# %%
#create 2014 df
census_2014df = pd.DataFrame(census_2014)
census_2014df = census_2014df.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count", "state":"state_id", "county":"county_id"})
census_2014df.head()
# Out:
#                         NAME  Household Income  Population  Median Age  \
# 0   Madison County, Illinois           53912.0    267937.0        39.2
# 1    Mercer County, Illinois           51259.0     16204.0        44.3
# 2  Sangamon County, Illinois           55565.0    198808.0        39.7
# 3  Randolph County, Illinois           48901.0     33091.0        41.6
# 4      Ogle County, Illinois           55894.0     52782.0        41.1
#
#    Per Capita Income  Poverty Count state_id county_id
# 0            28093.0        36365.0       17       119
# 1            26739.0         1736.0       17       131
# 2            30594.0        29045.0       17       167
# 3            22771.0         3656.0       17       157
# 4            27337.0         5734.0       17       141

# %%
#create census year column
census_year = "2014"
census_2014df["census_year"]=census_year
census_2014df.head()
# Out:
#                         NAME  Household Income  Population  Median Age  \
# 0   Madison County, Illinois           53912.0    267937.0        39.2
# 1    Mercer County, Illinois           51259.0     16204.0        44.3
# 2  Sangamon County, Illinois           55565.0    198808.0        39.7
# 3  Randolph County, Illinois           48901.0     33091.0        41.6
# 4      Ogle County, Illinois           55894.0     52782.0        41.1
#
#    Per Capita Income  Poverty Count state_id county_id census_year
# 0            28093.0        36365.0       17       119        2014
# 1            26739.0         1736.0       17       131        2014
# 2            30594.0        29045.0       17       167        2014
# 3            22771.0         3656.0       17       157        2014
# 4            27337.0         5734.0       17       141        2014

# %%
#split name column into county and state columns
census_2014df[["county", "state"]] = census_2014df.NAME.str.split(",",expand=True)
census_2014df.head()
# Out:
#                         NAME  Household Income  Population  Median Age  \
# 0   Madison County, Illinois           53912.0    267937.0        39.2
# 1    Mercer County, Illinois           51259.0     16204.0        44.3
# 2  Sangamon County, Illinois           55565.0    198808.0        39.7
# 3  Randolph County, Illinois           48901.0     33091.0        41.6
# 4      Ogle County, Illinois           55894.0     52782.0        41.1
#
#    Per Capita Income  Poverty Count state_id county_id census_year  \
# 0            28093.0        36365.0       17       119        2014
# 1            26739.0         1736.0       17       131        2014
# 2            30594.0        29045.0       17       167        2014
# 3            22771.0         3656.0       17       157        2014
# 4            27337.0         5734.0       17       141        2014
#
#             county      state
# 0   Madison County   Illinois
# 1    Mercer County   Illinois
# 2  Sangamon County   Illinois
# 3  Randolph County   Illinois
# 4      Ogle County   Illinois

# %%
#split string to be county name only
census_2014df['county2'] = census_2014df['county'].str.split(' ').str[0]
census_2014df.head()
# Out:
#                         NAME  Household Income  Population  Median Age  \
# 0   Madison County, Illinois           53912.0    267937.0        39.2
# 1    Mercer County, Illinois           51259.0     16204.0        44.3
# 2  Sangamon County, Illinois           55565.0    198808.0        39.7
# 3  Randolph County, Illinois           48901.0     33091.0        41.6
# 4      Ogle County, Illinois           55894.0     52782.0        41.1
#
#    Per Capita Income  Poverty Count state_id county_id census_year  \
# 0            28093.0        36365.0       17       119        2014
# 1            26739.0         1736.0       17       131        2014
# 2            30594.0        29045.0       17       167        2014
# 3            22771.0         3656.0       17       157        2014
# 4            27337.0         5734.0       17       141        2014
#
#             county      state   county2
# 0   Madison County   Illinois   Madison
# 1    Mercer County   Illinois    Mercer
# 2  Sangamon County   Illinois  Sangamon
# 3  Randolph County   Illinois  Randolph
# 4      Ogle County   Illinois      Ogle

# %%
#drop old county column
census_2014df = census_2014df.drop(['county'], axis=1)
census_2014df.head()
# Out:
#                         NAME  Household Income  Population  Median Age  \
# 0   Madison County, Illinois           53912.0    267937.0        39.2
# 1    Mercer County, Illinois           51259.0     16204.0        44.3
# 2  Sangamon County, Illinois           55565.0    198808.0        39.7
# 3  Randolph County, Illinois           48901.0     33091.0        41.6
# 4      Ogle County, Illinois           55894.0     52782.0        41.1
#
#    Per Capita Income  Poverty Count state_id county_id census_year      state  \
# 0            28093.0        36365.0       17       119        2014   Illinois
# 1            26739.0         1736.0       17       131        2014   Illinois
# 2            30594.0        29045.0       17       167        2014   Illinois
# 3            22771.0         3656.0       17       157        2014   Illinois
# 4            27337.0         5734.0       17       141        2014   Illinois
#
#     county2
# 0   Madison
# 1    Mercer
# 2  Sangamon
# 3  Randolph
# 4      Ogle

# %%
#drop old name column
census_2014df = census_2014df.drop(["NAME"], axis=1)
census_2014df.head()
# Out:
#    Household Income  Population  Median Age  Per Capita Income  Poverty Count  \
# 0           53912.0    267937.0        39.2            28093.0        36365.0
# 1           51259.0     16204.0        44.3            26739.0         1736.0
# 2           55565.0    198808.0        39.7            30594.0        29045.0
# 3           48901.0     33091.0        41.6            22771.0         3656.0
# 4           55894.0     52782.0        41.1            27337.0         5734.0
#
#   state_id county_id census_year      state   county2
# 0       17       119        2014   Illinois   Madison
# 1       17       131        2014   Illinois    Mercer
# 2       17       167        2014   Illinois  Sangamon
# 3       17       157        2014   Illinois  Randolph
# 4       17       141        2014   Illinois      Ogle

# %%
#rename county2 to county
census_2014df = census_2014df.rename(columns={"county2": "county"})
census_2014df.head()
# Out:
#    Household Income  Population  Median Age  Per Capita Income  Poverty Count  \
# 0           53912.0    267937.0        39.2            28093.0        36365.0
# 1           51259.0     16204.0        44.3            26739.0         1736.0
# 2           55565.0    198808.0        39.7            30594.0        29045.0
# 3           48901.0     33091.0        41.6            22771.0         3656.0
# 4           55894.0     52782.0        41.1            27337.0         5734.0
#
#   state_id county_id census_year      state    county
# 0       17       119        2014   Illinois   Madison
# 1       17       131        2014   Illinois    Mercer
# 2       17       167        2014   Illinois  Sangamon
# 3       17       157        2014   Illinois  Randolph
# 4       17       141        2014   Illinois      Ogle

# %%
#start 2018 session
c = Census(api_key, year = 2018)

# %%
#state & county level data call
census_2018= c.acs5.state_county(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E"), "17", "*")

# %%
#create 2018 df
census_2018df = pd.DataFrame(census_2018)
census_2018df = census_2018df.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count", "state":"state_id", "county":"county_id"})
census_2018df.head()
# Out:
#                         NAME  Household Income  Population  Median Age  \
# 0   Hancock County, Illinois           51549.0     18112.0        46.0
# 1   Madison County, Illinois           57890.0    265670.0        40.1
# 2    Grundy County, Illinois           74140.0     50509.0        37.6
# 3  Kankakee County, Illinois           57981.0    111061.0        37.6
# 4    Mercer County, Illinois           58011.0     15693.0        44.8
#
#    Per Capita Income  Poverty Count state_id county_id
# 0            26880.0         2132.0       17       067
# 1            30802.0        35625.0       17       119
# 2            33308.0         4389.0       17       063
# 3            27164.0        15794.0       17       091
# 4            28995.0         1762.0       17       131

# %%
#create census year column
census_year = "2018"
census_2018df["census_year"]=census_year
census_2018df.head()
# Out:
#                         NAME  Household Income  Population  Median Age  \
# 0   Hancock County, Illinois           51549.0     18112.0        46.0
# 1   Madison County, Illinois           57890.0    265670.0        40.1
# 2    Grundy County, Illinois           74140.0     50509.0        37.6
# 3  Kankakee County, Illinois           57981.0    111061.0        37.6
# 4    Mercer County, Illinois           58011.0     15693.0        44.8
#
#    Per Capita Income  Poverty Count state_id county_id census_year
# 0            26880.0         2132.0       17       067        2018
# 1            30802.0        35625.0       17       119        2018
# 2            33308.0         4389.0       17       063        2018
# 3            27164.0        15794.0       17       091        2018
# 4            28995.0         1762.0       17       131        2018

# %%
#split name column into county and state columns
census_2018df[["county", "state"]] = census_2018df.NAME.str.split(",",expand=True)
census_2018df.head()
# Out:
#                         NAME  Household Income  Population  Median Age  \
# 0   Hancock County, Illinois           51549.0     18112.0        46.0
# 1   Madison County, Illinois           57890.0    265670.0        40.1
# 2    Grundy County, Illinois           74140.0     50509.0        37.6
# 3  Kankakee County, Illinois           57981.0    111061.0        37.6
# 4    Mercer County, Illinois           58011.0     15693.0        44.8
#
#    Per Capita Income  Poverty Count state_id county_id census_year  \
# 0            26880.0         2132.0       17       067        2018
# 1            30802.0        35625.0       17       119        2018
# 2            33308.0         4389.0       17       063        2018
# 3            27164.0        15794.0       17       091        2018
# 4            28995.0         1762.0       17       131        2018
#
#             county      state
# 0   Hancock County   Illinois
# 1   Madison County   Illinois
# 2    Grundy County   Illinois
# 3  Kankakee County   Illinois
# 4    Mercer County   Illinois

# %%
#split string to be county name only
census_2018df['county2'] = census_2018df['county'].str.split(' ').str[0]
census_2018df.head()
# Out:
#                         NAME  Household Income  Population  Median Age  \
# 0   Hancock County, Illinois           51549.0     18112.0        46.0
# 1   Madison County, Illinois           57890.0    265670.0        40.1
# 2    Grundy County, Illinois           74140.0     50509.0        37.6
# 3  Kankakee County, Illinois           57981.0    111061.0        37.6
# 4    Mercer County, Illinois           58011.0     15693.0        44.8
#
#    Per Capita Income  Poverty Count state_id county_id census_year  \
# 0            26880.0         2132.0       17       067        2018
# 1            30802.0        35625.0       17       119        2018
# 2            33308.0         4389.0       17       063        2018
# 3            27164.0        15794.0       17       091        2018
# 4            28995.0         1762.0       17       131        2018
#
#             county      state   county2
# 0   Hancock County   Illinois   Hancock
# 1   Madison County   Illinois   Madison
# 2    Grundy County   Illinois    Grundy
# 3  Kankakee County   Illinois  Kankakee
# 4    Mercer County   Illinois    Mercer

# %%
#drop old county column
census_2018df = census_2018df.drop(['county'], axis=1)
census_2018df.head()
# Out:
#                         NAME  Household Income  Population  Median Age  \
# 0   Hancock County, Illinois           51549.0     18112.0        46.0
# 1   Madison County, Illinois           57890.0    265670.0        40.1
# 2    Grundy County, Illinois           74140.0     50509.0        37.6
# 3  Kankakee County, Illinois           57981.0    111061.0        37.6
# 4    Mercer County, Illinois           58011.0     15693.0        44.8
#
#    Per Capita Income  Poverty Count state_id county_id census_year      state  \
# 0            26880.0         2132.0       17       067        2018   Illinois
# 1            30802.0        35625.0       17       119        2018   Illinois
# 2            33308.0         4389.0       17       063        2018   Illinois
# 3            27164.0        15794.0       17       091        2018   Illinois
# 4            28995.0         1762.0       17       131        2018   Illinois
#
#     county2
# 0   Hancock
# 1   Madison
# 2    Grundy
# 3  Kankakee
# 4    Mercer

# %%
#drop old name column
census_2018df = census_2018df.drop(["NAME"], axis=1)
census_2018df.head()
# Out:
#    Household Income  Population  Median Age  Per Capita Income  Poverty Count  \
# 0           51549.0     18112.0        46.0            26880.0         2132.0
# 1           57890.0    265670.0        40.1            30802.0        35625.0
# 2           74140.0     50509.0        37.6            33308.0         4389.0
# 3           57981.0    111061.0        37.6            27164.0        15794.0
# 4           58011.0     15693.0        44.8            28995.0         1762.0
#
#   state_id county_id census_year      state   county2
# 0       17       067        2018   Illinois   Hancock
# 1       17       119        2018   Illinois   Madison
# 2       17       063        2018   Illinois    Grundy
# 3       17       091        2018   Illinois  Kankakee
# 4       17       131        2018   Illinois    Mercer

# %%
#rename county2 to county
census_2018df = census_2018df.rename(columns={"county2": "county"})
census_2018df.head()
# Out:
#    Household Income  Population  Median Age  Per Capita Income  Poverty Count  \
# 0           51549.0     18112.0        46.0            26880.0         2132.0
# 1           57890.0    265670.0        40.1            30802.0        35625.0
# 2           74140.0     50509.0        37.6            33308.0         4389.0
# 3           57981.0    111061.0        37.6            27164.0        15794.0
# 4           58011.0     15693.0        44.8            28995.0         1762.0
#
#   state_id county_id census_year      state    county
# 0       17       067        2018   Illinois   Hancock
# 1       17       119        2018   Illinois   Madison
# 2       17       063        2018   Illinois    Grundy
# 3       17       091        2018   Illinois  Kankakee
# 4       17       131        2018   Illinois    Mercer

# %%
#view df description to see n of rows
census_2010df.describe()
# Out:
#        Household Income    Population  Median Age  Per Capita Income  \
# count        102.000000  1.020000e+02  102.000000         102.000000
# mean       47184.950980  1.249545e+05   40.059804       23552.980392
# std        10286.935272  5.248368e+05    3.655980        3839.921289
# min        27578.000000  4.402000e+03   28.400000       15858.000000
# 25%        40917.250000  1.481025e+04   39.025000       21150.250000
# 50%        45141.000000  2.761950e+04   40.850000       23197.500000
# 75%        50806.750000  5.357550e+04   42.300000       25051.000000
# max        79897.000000  5.172848e+06   46.600000       38120.000000
#
#        Poverty Count
# count     102.000000
# mean    15412.235294
# std     77179.066606
# min       484.000000
# 25%      1584.250000
# 50%      2795.500000
# 75%      7365.500000
# max    778340.000000

# %%
#view df description to see n of rows
census_2014df.describe()
# Out:
#        Household Income    Population  Median Age  Per Capita Income  \
# count        102.000000  1.020000e+02  102.000000         102.000000
# mean       49765.519608  1.261642e+05   41.046078       25164.137255
# std        10025.998361  5.307016e+05    3.846657        3936.257704
# min        25495.000000  4.226000e+03   29.200000       14052.000000
# 25%        43312.500000  1.453250e+04   39.625000       22666.000000
# 50%        48284.500000  2.707400e+04   41.650000       24808.500000
# 75%        53085.750000  5.391750e+04   43.275000       26899.750000
# max        83844.000000  5.227827e+06   49.100000       38931.000000
#
#        Poverty Count
# count     102.000000
# mean    17749.705882
# std     88033.521620
# min       521.000000
# 25%      1772.500000
# 50%      3252.000000
# 75%      7505.500000
# max    886261.000000

# %%
#view df description to see n of rows
census_2018df.describe()
# Out:
#        Household Income    Population  Median Age  Per Capita Income  \
# count        102.000000  1.020000e+02  102.000000         102.000000
# mean       54839.617647  1.257010e+05   41.740196       28297.509804
# std        11021.734681  5.305819e+05    3.802820        4420.213900
# min        33799.000000  4.009000e+03   29.900000       19065.000000
# 25%        48699.250000  1.405750e+04   40.100000       25584.500000
# 50%        52671.000000  2.620000e+04   42.300000       27577.000000
# 75%        57961.000000  5.313850e+04   43.600000       29872.000000
# max        91764.000000  5.223719e+06   53.700000       44287.000000
#
#        Poverty Count
# count     102.000000
# mean    16035.323529
# std     77314.395264
# min       482.000000
# 25%      1744.750000
# 50%      3051.000000
# 75%      7295.250000
# max    778020.000000

# %%
#create combined df with 2010df as base data
census_all = census_2010df

# %%
#view df description to see n of rows
census_all.describe()
# Out:
#        Household Income    Population  Median Age  Per Capita Income  \
# count        102.000000  1.020000e+02  102.000000         102.000000
# mean       47184.950980  1.249545e+05   40.059804       23552.980392
# std        10286.935272  5.248368e+05    3.655980        3839.921289
# min        27578.000000  4.402000e+03   28.400000       15858.000000
# 25%        40917.250000  1.481025e+04   39.025000       21150.250000
# 50%        45141.000000  2.761950e+04   40.850000       23197.500000
# 75%        50806.750000  5.357550e+04   42.300000       25051.000000
# max        79897.000000  5.172848e+06   46.600000       38120.000000
#
#        Poverty Count
# count     102.000000
# mean    15412.235294
# std     77179.066606
# min       484.000000
# 25%      1584.250000
# 50%      2795.500000
# 75%      7365.500000
# max    778340.000000

# %%
#append 2014 data and vier df description to ensure all rows were appended
census_all = census_all.append(census_2014df, ignore_index=True)
census_all.describe()
# Out:
#        Household Income    Population  Median Age  Per Capita Income  \
# count        204.000000  2.040000e+02  204.000000         204.000000
# mean       48475.235294  1.255593e+05   40.552941       24358.558824
# std        10214.482084  5.264762e+05    3.775777        3961.973367
# min        25495.000000  4.226000e+03   28.400000       14052.000000
# 25%        41765.250000  1.467950e+04   39.200000       21879.500000
# 50%        46688.000000  2.722150e+04   41.400000       24012.000000
# 75%        52267.500000  5.374250e+04   42.725000       26390.750000
# max        83844.000000  5.227827e+06   49.100000       38931.000000
#
#        Poverty Count
# count     204.000000
# mean    16580.970588
# std     82588.542919
# min       484.000000
# 25%      1723.500000
# 50%      3088.500000
# 75%      7528.500000
# max    886261.000000

# %%
#append 2018 data and vier df description to ensure all rows were appended
census_all = census_all.append(census_2018df, ignore_index=True)
census_all.describe()
# Out:
#        Household Income    Population  Median Age  Per Capita Income  \
# count        306.000000  3.060000e+02  306.000000         306.000000
# mean       50596.696078  1.256065e+05   40.948693       25671.542484
# std        10895.004513  5.269778e+05    3.819932        4514.075779
# min        25495.000000  4.009000e+03   28.400000       14052.000000
# 25%        43340.500000  1.445425e+04   39.325000       22613.750000
# 50%        49084.500000  2.667000e+04   41.600000       25067.000000
# 75%        54640.250000  5.364275e+04   43.100000       28068.000000
# max        91764.000000  5.227827e+06   53.700000       44287.000000
#
#        Poverty Count
# count     306.000000
# mean    16399.088235
# std     80742.160345
# min       482.000000
# 25%      1736.750000
# 50%      3057.500000
# 75%      7511.250000
# max    886261.000000

# %%
census_all
# Out:
#      Household Income  Population  Median Age  Per Capita Income  \
# 0             43824.0     67030.0        40.4            24308.0
# 1             28833.0      8449.0        41.8            15858.0
# 2             51946.0     17904.0        39.3            24341.0
# 3             61210.0     53567.0        35.8            26105.0
# 4             38696.0      6897.0        37.6            17133.0
# ..                ...         ...         ...                ...
# 301           56747.0     22069.0        42.7            28924.0
# 302           44432.0     21724.0        41.5            22260.0
# 303           57899.0     29207.0        40.4            27187.0
# 304           41167.0     24231.0        42.0            23690.0
# 305           86244.0    703619.0        38.2            44287.0
#
#      Poverty Count state_id county_id census_year      state     county
# 0           7954.0       17       001        2010   Illinois      Adams
# 1           1600.0       17       003        2010   Illinois  Alexander
# 2           1870.0       17       005        2010   Illinois       Bond
# 3           5508.0       17       007        2010   Illinois      Boone
# 4            555.0       17       009        2010   Illinois      Brown
# ..             ...      ...       ...         ...        ...        ...
# 301         1944.0       17       083        2018   Illinois     Jersey
# 302         3551.0       17       051        2018   Illinois    Fayette
# 303         2143.0       17       107        2018   Illinois      Logan
# 304         5260.0       17       165        2018   Illinois     Saline
# 305        56651.0       17       097        2018   Illinois       Lake
#
# [306 rows x 10 columns]

# %%
#create variables for county pk table
county_idx = census_all['county_id'].unique()
county_namex = census_all['county'].unique()

print(len(county_idx))
# Out:
# 102

# %%
#create county primary key table
county_pk_df = pd.DataFrame({"county_id":county_idx, "county_name": county_namex})
county_pk_df
# Out:
#     county_id county_name
# 0         001       Adams
# 1         003   Alexander
# 2         005        Bond
# 3         007       Boone
# 4         009       Brown
# ..        ...         ...
# 97        195   Whiteside
# 98        197        Will
# 99        199  Williamson
# 100       201   Winnebago
# 101       203    Woodford
#
# [102 rows x 2 columns]

# %%
county_pk_df.to_csv("census_data/county_id.csv")
census_all.to_csv("census_data/census.csv")
